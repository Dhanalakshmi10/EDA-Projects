# %% [markdown]
# # EDA Assignment Dhanalakshmi 10drossdl@gmail.com

# %%
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_excel(r"C:\\Users\Parth\Desktop\EDA_MIT\EDA and FE-Graded Assignment\IPL.xlsx")

# %%
df=df1.copy() #creating a data frame copy as i don't want to make any changes to the original

# %%
df.info() #Wanted to get a basic idea about the data. Also wanted to see if there were any null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
df.head()
# Out:
#    Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0       1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1       2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2       3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3       4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4       5  Badrinath, S    2     IND   CSK      Batsman      63       0
#
#    ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# 0           0      0.00  ...    0.00       0     307    15   20.47   8.90
# 1         657     71.41  ...    0.00       0      29     0    0.00  14.50
# 2        1269     80.62  ...  121.01       5    1059    29   36.52   8.81
# 3         241     84.56  ...   76.32       0    1125    49   22.96   6.23
# 4          79     45.93  ...  120.71      28       0     0    0.00   0.00
#
#    SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %%
df.tail()
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL  ECON  \
# 125           0      0.00  ...  125.64       2       0     0    0.00  0.00
# 126        6814     75.78  ...   42.85       0       0     0    0.00  0.00
# 127        8051     87.58  ...  131.88      67     569    23   24.74  7.02
# 128         790     73.55  ...   91.67       1    1783    65   27.43  7.75
# 129         343     95.81  ...  122.22       0      99     2   49.50  9.00
#
#      SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# ...

# %% [markdown]
# ### Q1)	Plot the following charts (as shown in below fig.,) and mention any two inferences.

# %%
plt.figure(figsize=(15,10))
sns.barplot(x="AGE",y="SOLD PRICE",data=df, hue="PLAYING ROLE") 
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.histplot(x="COUNTRY",data=df, hue="PLAYING ROLE",kde=True)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x="COUNTRY",y="SOLD PRICE",data=df)
plt.show()

# %% [markdown]
# #### INFERENCE:
# 1. From the barplot we see that a batsman belonging to Age group 1 was sold for the highest price. And no wicket keeper was sold in the age group 1.
#
# 2. From the histogram we see that there are high number of Indian cricket players in IPL auction , especially batsman and bowlers. From the same graph we can also see that the least number of players included in IPL auction were from the country Bangaladesh (mostly bowlers) and Zimbabwe (mostly wicket keepers)
#
# 3. From the box plot we see that there were few players from IND, AUS, WI countries who were sold for extreme prices than any another coutries in general ( we know this from the outliers). We also see that, most of the England players were sold for high prices as compared to others.

# %% [markdown]
# ### 2) It has been observed that one/few outliers are present in the variable ‘SOLD PRICE’.
# i) Draw a box plot for ‘SOLD PRICE’ with outliers & find the value of IQR, Upper limit & lower limit.

# %%
#box plot using seaborn
plt.figure(figsize=(8,5))
sns.boxplot(x="SOLD PRICE",data=df)
plt.show()

# %%
#box plot using matplotlib
plt.figure(figsize=(10,8))
outlier_shape=dict(marker='+')
plt.boxplot(x="SOLD PRICE",data=df,vert=False, flierprops=outlier_shape)
plt.show()

# %%
# IQR calculation
Q1 = df["SOLD PRICE"].quantile(0.25) 
Q3 = df["SOLD PRICE"].quantile(0.75)   
IQR = Q3 - Q1
Upper_Limit = Q3 + 1.5*IQR
Lower_Limit = Q1 - 1.5*IQR
print(f'Interquartile Range of Sold Price is {IQR} INR')
print(f'Sold price Upper Limit is {Upper_Limit} INR and Lower limit is {Lower_Limit} INR')
# Out:
# Interquartile Range of Sold Price is 475000.0 INR
# Sold price Upper Limit is 1412500.0 INR and Lower limit is -487500.0 INR

# %% [markdown]
# ii) Remove outliers & draw the box plot.

# %%
outlier_df=df.copy() # creating a copy df as i do not want to make changes to my working df
Without_Outliers=outlier_df[(outlier_df['SOLD PRICE']>=Lower_Limit) & (outlier_df['SOLD PRICE']<=Upper_Limit)]
Without_Outliers
#we see that initially there were 130 entries, now there are only 122. 8 values have been removed.
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND   KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND   CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND   CSK      Batsman      63       0
# ..      ...           ...  ...     ...   ...          ...     ...     ...
# 124     125     White, CL    2     AUS  RCB+      Batsman     146       5
# 125     126     Yadav, AS    2     IND    DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK    RR      Batsman    6398       7
# 128     129   Zaheer Khan    2     IND   MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL    DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# ...

# %%
sns.boxplot(y='SOLD PRICE',data=Without_Outliers)
#no outliers are seen
# Out:
# <AxesSubplot:ylabel='SOLD PRICE'>

# %%
#I have only removed the outliers, did not replace or use any other method as it was not asked in the question.

# %% [markdown]
# ### Q3) Assume that we would like to filter certain records such as the players who have hit more than 80 sixers in the IPL tournament. Write a code to display the data frame with only the player name & sixers, for the same.

# %%
Sixers_data=df[df['SIXERS']> 80]
Sixers_data[['PLAYER NAME','SIXERS']].sort_values(by='SIXERS',ascending=False)
# Out:
#       PLAYER NAME  SIXERS
# 26      Gayle, CH     129
# 88      Raina, SK      97
# 28  Gilchrist, AC      86
# 97     Sharma, RG      82
# 82     Pathan, YK      81
